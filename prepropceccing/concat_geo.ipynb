# %%
import os
import zipfile
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
# === 1. Распаковка архива ===
zip_path = "DataGeoEPCI.zip"
extract_path = "DataGeoEPCI_extracted"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# === 2. Извлечение .geojson файлов ===
inner_dir = os.path.join(extract_path, 'DataGeoEPCI')
print(inner_dir)
geojson_files = [f for f in os.listdir(inner_dir) if f.endswith('.geojson')]
print(geojson_files)
# Out:
# DataGeoEPCI_extracted\DataGeoEPCI
# ['1-guadeloupe-reduit.geojson', '11-iledefrance-reduit.geojson', '2-martinique-reduit.geojson', '24-centrevaldeloire-reduit.geojson', '27-bourgognefranchecompte-reduit.geojson', '28-normandie-reduit.geojson', '3-guyane-reduit.geojson', '32-hautsdefrance-reduit.geojson', '4-lareunion-reduit.geojson', '44-grandest-reduit.geojson', '52-paysdelaloire-reduit.geojson', '53-bretagne-reduit.geojson', '6-mayotte-reduit.geojson', '75-nouvelleaquitaine-reduit.geojson', '76-occitanie-reduit.geojson', '84-auvergnerohnealpes-reduit.geojson', '93-paca-reduit.geojson', '94-corse-reduit.geojson']

# %%
# === 3. Объединение всех properties ===
all_records = []

for file in geojson_files:
    file_path = os.path.join(inner_dir, file)
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    for feature in data['features']:
        props = feature['properties']
        props['source_file'] = file
        all_records.append(props)
